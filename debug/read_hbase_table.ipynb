# %%
import happybase as hb

# %%
con = hb.Connection("localhost")

# %%
con.open()
con.tables()
# Out:
# [b'books',
#  b'employees',
#  b'f1',
#  b'f1-new1',
#  b'orders_table',
#  b'person',
#  b'prog_langs',
#  b'region_borders',
#  b'test',
#  b'test2',
#  b'test_files',
#  b'trains',
#  b'trees',
#  b'tweets',
#  b'vehicles',
#  b'wifi',
#  b'zad2020-3']

# %%
table = con.table("region_borders")

# %%
for a in table.scan():
    print(a)
# Out:
# (b'dzielnice_Warszawy', {b'map_files:cpg': b'UTF-8', b'map_files:dbf': b'\x03w\n\x11\x12\x00\x00\x00A\x00\xff\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00nazwa_dzie\x00C\x00\x00\x00\x00\xfe\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\r \xc5\xbboliborz                                                                                                                                                                                                                                                      Praga-Po\xc5\x82udnie                                                                                                                                                                                                                                                Mokot\xc3\xb3w                                                                                                                                                                           
# ...
